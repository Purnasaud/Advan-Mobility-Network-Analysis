# %% [markdown]
# ### ***1 Setup and Configurations***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import importlib
import sys
sys.path.append(r"F:\Yellow Stone Flood-2022\floodanalysis\Data\Advan Mobility")
warnings.filterwarnings('ignore')

# Import local modules (these MUST be in the same folder as this notebook)
import advan_mobility_config as confi
import advan_mobility_visualization_functions as viz

# Apply plot style
confi.setup_plot_style()
print ("Module imported successfully")
importlib.reload(viz) 

# Load data
data, time_periods, counties, covid_idx = viz.load_data()
# Out:
# Module imported successfully

# %% [markdown]
# ### ***2. Heatmaps Visualizations***

# %%
viz.generate_all_heatmaps(confi.KEY_METRICS, top_n=15)
# Out:
# Saved: Heatmap_InDegree_Top15.png
# Saved: Heatmap_OutDegree_Top15.png
# Saved: Heatmap_Weighted_InStrength_Top15.png
# Saved: Heatmap_Weighted_OutStrength_Top15.png
# Saved: Heatmap_PageRank_Top15.png
# Saved: Heatmap_Betweenness_Top15.png
# Saved: Heatmap_Closeness_Top15.png
# Saved: Heatmap_Eigenvector_Top15.png

# %%
viz.plot_heatmap(
    'Weighted_InStrength',
    top_n=20,
    savepath=confi. OUTPUT_DIR / "Custom_Heatmap_WeightedInStrength_Top20.png"
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 viz.plot_heatmap(
#       2     'Weighted_InStrength',
#       3     top_n=20,
#       4     savepath=confi. OUTPUT_DIR / "Custom_Heatmap_WeightedInStrength_Top20.png"
#       5 )
#
# File d:\WY-COVID Data\.wycovidanalysis\advan_mobility_visualization_functions.py:202, in plot_heatmap(metric_name, df, top_n, savepath)
#     187 """
#     188 Heatmap showing metric values across time for top counties.
#     189
#    (...)
#     199     Path to save figure
#     200 """
#     201 if df is None:
# --> 202     df = data[metric_name]
#     204 # Sort by mean and get top N
#     205 county_order = df.mean(axis=1).sort_values(ascending=False).index.tolist()
#
# KeyError: 'Weighted_InStrength'
